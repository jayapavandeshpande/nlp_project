# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Importing necessary python libraries and modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from timeit import default_timer as timer

# %%
# Reading the dataset

df = pd.read_excel('dataset/input_data.xlsx')
df.head()
# Out:
#                Short description  \
# 0                    login issue
# 1                        outlook
# 2             cant log in to vpn
# 3  unable to access hr_tool page
# 4                   skype error
#
#                                          Description             Caller  \
# 0  -verified user details.(employee# & manager na...  spxjnwir pjlcoqds
# 1  \r\n\r\nreceived from: hmjdrvpb.komuaywn@gmail...  hmjdrvpb komuaywn
# 2  \r\n\r\nreceived from: eylqgodm.ybqkwiam@gmail...  eylqgodm ybqkwiam
# 3                      unable to access hr_tool page  xbkucsvz gcpydteq
# 4                                       skype error   owlgqjme qhcozdfx
#
#   Assignment group
# 0            GRP_0
# 1            GRP_0
# 2            GRP_0
# 3            GRP_0
# 4            GRP_0

# %%
# Checking for null values

df.isnull().sum()
# Out:
# Short description    8
# Description          1
# Caller               0
# Assignment group     0
# dtype: int64

# %%
# Filtering dataset with Null values.

df[pd.isnull(df).any(axis=1)]
# Out:
#              Short description  \
# 2604                       NaN
# 3383                       NaN
# 3906                       NaN
# 3910                       NaN
# 3915                       NaN
# 3921                       NaN
# 3924                       NaN
# 4341                       NaN
# 4395  i am locked out of skype
#
#                                             Description             Caller  \
# 2604  \r\n\r\nreceived from: ohdrnswl.rezuibdt@gmail...  ohdrnswl rezuibdt
# 3383  \r\n-connected to the user system using teamvi...  qftpazns fxpnytmk
# 3906  -user unable  tologin to vpn.\r\n-connected to...  awpcmsey ctdiuqwe
# 3910  -user unable  tologin to vpn.\r\n-connected to...  rhwsmefo tvphyura
# 3915  -user unable  tologin to vpn.\r\n-connected to...  hxripljo efzounig
# 3921  -user unable  tologin to vpn.\r\n-connected to...  cziadygo veiosxby
# 3924  name:wvqgbdhm fwchqjor\nlanguage:\nbrowser:mic...  wvqgbdhm fwchqjor
# ...

# %%
# Replacing Null values with values from adjacent columns

df['Short description'].fillna(df['Description'],inplace=True)
df['Description'].fillna(df['Short description'],inplace=True)
df.isna().sum()
# Out:
# Short description    0
# Description          0
# Caller               0
# Assignment group     0
# dtype: int64

# %% [markdown]
# ### Fix garbled text (Mojibake)

# %%
# import sys
# sys.path.append('/content/drive/My Drive/Colab Notebooks/Capstone/Modules/')

# %%
# %%capture
from utils.textPreprocess import *
# from textPreprocess import mojifix

# %%
# Mojibake fixing for "Description"

df,count = mojifix(df,1)
print("Garbled text count: ",count)
df,count = mojifix(df,1)
print("Garbled text count after Mojibake fix: ",count)
print("\nSample O/p of text not converted")
print("="*32)
print("df['Description'][5910]: ",df['Description'][5910])
print("\ndf['Description'][177]:\n",df.Description[177])
# Out:
# Garbled text count:  788
# Garbled text count after Mojibake fix:  45
#
# Sample O/p of text not converted
# ...
# df['Description'][5910]:  laptop 从桌子上面摔下,外壳摔裂,现在不能开机。
#
# df['Description'][177]:
#  b'i try to change now my password acc. to attached e-mail but this don\xb4t work. i was out of office for vacation time until now, but\npassword_management_tool link don\xb4t work - please help\n\n\n\nyour password expires in 13 day(s) \n\nthe requirement to change your password every 90 days enhances data security within company. \n\nplease login to \na step-by-step guide on using the self-service tool is available here: \n\nplease do not reply to this email. if you require assistance, please submit a ticket to the global support center via any of these modes: \n\nticketing_tool: \nemail: help@company.com \n\nkind '

# %%
# Mojibake fixing for "Short description"

df,count = mojifix(df,0)
print("Garbled text count: ",count)
df,count = mojifix(df,0)
print("Garbled text count after Mojibake fix: ",count)
# Out:
# Garbled text count:  351
# Garbled text count after Mojibake fix:  34

# %% [markdown]
# ### Foreign language detection

# %%
# from utils.textPreprocess import detect_lang,plot_lang
from utils.textPreprocess import *
import fasttext

df = df.replace('\n',' ', regex=True)

df = detect_lang(df,0,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5cc8261b3c42> in <module>
#       5 df = df.replace('\n',' ', regex=True)
#       6
# ----> 7 df = detect_lang(df,0,1)
#
# h:\PGP_AIML\11.Capstone\CapstoneGIT2\nlp_project\utils\textPreprocess.py in detect_lang(df, col_1, col_2, summary)
#      39
#      40 def detect_lang(df,col_1,col_2,summary=True):
# ---> 41     lid = fasttext.load_model('/lid/lid.176.ftz')
#      42
#      43     df['iso_Short'] = ''
#
# NameError: name 'fasttext' is not defined

# %%
plot_lang(df,0,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7d949247f789> in <module>
# ----> 1 plot_lang(df,0,1)
#
# h:\PGP_AIML\11.Capstone\CapstoneGIT2\nlp_project\utils\textPreprocess.py in plot_lang(df, col_1, col_2)
#     112
#     113 def plot_lang(df,col_1,col_2):
# --> 114     df = detect_lang(df,col_1,col_2,summary=False)
#     115     fig, axarr = plt.subplots(1, 2, figsize=(12, 12))
#     116     axarr[0].pie(df['lang_Short'].value_counts()[1:],autopct='%1.1f%%',pctdistance=1.1,startangle=180)
#
# h:\PGP_AIML\11.Capstone\CapstoneGIT2\nlp_project\utils\textPreprocess.py in detect_lang(df, col_1, col_2, summary)
#      39
#      40 def detect_lang(df,col_1,col_2,summary=True):
# ---> 41     lid = fasttext.load_model('/lid/lid.176.ftz')
#      42
#      43     df['iso_Short'] = ''
#
# NameError: name 'fasttext' is not defined

# %% [markdown]
# ### Foreign language translation to "English"

# %%
# from textPreprocess import lang_translator

start = timer()
lang_translator(df,0,1)
end = timer()
print("Time elapsed in seconds: ",end-start)
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-1b3563f5c155> in <module>
#       2
#       3 start = timer()
# ----> 4 lang_translator(df,0,1)
#       5 end = timer()
#       6 print("Time elapsed in seconds: ",end-start)
#
# h:\PGP_AIML\11.Capstone\CapstoneGIT2\nlp_project\utils\textPreprocess.py in lang_translator(df, col_1, col_2)
#      93     df['translated_Short'] = ''
#      94     df['translated_Desc'] = ''
# ---> 95     lid = FastText.load_model('lid/lid.176.ftz')
#      96     for i in range(df.shape[0]):
#      97         try:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\fasttext\FastText.py in load_model(path)
#     439     """Load a model given a filepath and return a model object."""
# ...

# %%
df
# Out:
#                                       Short description  \
# 0                                           login issue
# 1                                               outlook
# 2                                    cant log in to vpn
# 3                         unable to access hr_tool page
# 4                                          skype error
# ...                                                 ...
# 8495                  emails not coming in from zz mail
# 8496                           telephony_software issue
# 8497  vip2: windows password reset for tifpdchb pedx...
# 8498              b'machine n\xe3o est\xe1 funcionando'
# 8499  b'an mehreren pc`s lassen sich verschiedene pr...
#
#                                             Description             Caller  \
# 0     -verified user details.(employee# & manager na...  spxjnwir pjlcoqds
# 1     \r \r received from: hmjdrvpb.komuaywn@gmail.c...  hmjdrvpb komuaywn
# ...

# %%
print("Sample Output:")
print("==============")
out = pd.DataFrame({'Description':[df[df.columns[0]][3315],df[df.columns[1]][779],df[df.columns[0]][164]],
                    'ISO':[df[df.columns[4]][3315],df[df.columns[5]][779],df[df.columns[4]][164]],
                    'Language':[df[df.columns[6]][3315],df[df.columns[7]][779],df[df.columns[6]][164]],
                    'Translated Description':[df[df.columns[8]][3315],df[df.columns[9]][779],df[df.columns[8]][164]],
                    },
                   index=['3315','779','164'])
out
# Out:
# Sample Output:
# ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-89128552d38c> in <module>
#       3 out = pd.DataFrame({'Description':[df[df.columns[0]][3315],df[df.columns[1]][779],df[df.columns[0]][164]],
#       4                     'ISO':[df[df.columns[4]][3315],df[df.columns[5]][779],df[df.columns[4]][164]],
# ----> 5                     'Language':[df[df.columns[6]][3315],df[df.columns[7]][779],df[df.columns[6]][164]],
#       6                     'Translated Description':[df[df.columns[8]][3315],df[df.columns[9]][779],df[df.columns[8]][164]],
#       7                     },
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3928         if is_scalar(key):
#    3929             key = com.cast_scalar_indexer(key)
# -> 3930             return getitem(key)
# ...

# %%
# Translated Short description
df,count = mojifix(df,8)
print("Garbled text count: ",count)
df,count = mojifix(df,8)
print("Garbled text count after Mojibake fix: ",count)
# Translated Description
df,count = mojifix(df,9)
print("Garbled text count: ",count)
df,count = mojifix(df,9)
print("Garbled text count after Mojibake fix: ",count)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-22dd7b2d7c74> in <module>
#       1 # Translated Short description
# ----> 2 df,count = mojifix(df,8)
#       3 print("Garbled text count: ",count)
#       4 df,count = mojifix(df,8)
#       5 print("Garbled text count after Mojibake fix: ",count)
#
# h:\PGP_AIML\11.Capstone\CapstoneGIT2\nlp_project\utils\textPreprocess.py in mojifix(df, col_num)
#      23 #    df['mojibake'] = ''
#      24     for i in range(df.shape[0]):
# ---> 25         if badness.sequence_weirdness(str(df[df.columns[col_num]][i]))!=0:
#      26             j = j+1
#      27             try:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3928         if is_scalar(key):
#    3929             key = com.cast_scalar_indexer(key)
# ...

# %%
# Saving dataset to csv file

df.to_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_21_06_20.xlsx',index=False,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-e2476380da0f> in <module>
#       1 # Saving dataset to csv file
#       2
# ----> 3 df.to_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_21_06_20.xlsx',index=False,encoding='utf-8')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2179             startcol=startcol,
#    2180             freeze_panes=freeze_panes,
# -> 2181             engine=engine,
#    2182         )
#    2183
#
# ...

# %%
df_new = pd.read_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_21_06_20.xlsx')
df_new.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-23f8ad20ff2b> in <module>
# ----> 1 df_new = pd.read_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_21_06_20.xlsx')
#       2 df_new.head()
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ...

# %%
df_new.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-72a777ac61c8> in <module>
# ----> 1 df_new.isna().sum()
#
# NameError: name 'df_new' is not defined

# %%
df_new['Description'].fillna(df_new['Short description'],inplace=True)
df_new.translated_Short.fillna(df_new['Short description'],inplace=True)
df_new.translated_Desc.fillna(df_new['Description'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-7cbf6c6b5363> in <module>
# ----> 1 df_new['Description'].fillna(df_new['Short description'],inplace=True)
#       2 df_new.translated_Short.fillna(df_new['Short description'],inplace=True)
#       3 df_new.translated_Desc.fillna(df_new['Description'],inplace=True)
#
# NameError: name 'df_new' is not defined

# %%
df_new['Short description'] = df_new['translated_Short']
df_new['Description'] = df_new['translated_Desc']
df_new.drop(['iso_Short','iso_Desc','lang_Short','lang_Desc','translated_Short','translated_Desc'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a184f5f8d2f2> in <module>
# ----> 1 df_new['Short description'] = df_new['translated_Short']
#       2 df_new['Description'] = df_new['translated_Desc']
#       3 df_new.drop(['iso_Short','iso_Desc','lang_Short','lang_Desc','translated_Short','translated_Desc'],axis=1,inplace=True)
#
# NameError: name 'df_new' is not defined

# %%
df_new.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ac42e69273e3> in <module>
# ----> 1 df_new.head()
#
# NameError: name 'df_new' is not defined

# %%
# Language verification after translation
from textPreprocess import detect_lang
df_new = detect_lang(df_new,0,1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-a17d0ade6bfb> in <module>
#       1 # Language verification after translation
# ----> 2 from textPreprocess import detect_lang
#       3 df_new = detect_lang(df_new,0,1)
#
# ModuleNotFoundError: No module named 'textPreprocess'

# %%
from textPreprocess import plot_lang
plot_lang(df_new,0,1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-4da6ddc3084a> in <module>
# ----> 1 from textPreprocess import plot_lang
#       2 plot_lang(df_new,0,1)
#
# ModuleNotFoundError: No module named 'textPreprocess'

# %%
from textPreprocess import lang_translator
start = timer()
lang_translator(df_new,0,1)
end = timer()
print("Time elapsed in seconds: ",end-start)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-a120d3d82ee8> in <module>
# ----> 1 from textPreprocess import lang_translator
#       2 start = timer()
#       3 lang_translator(df_new,0,1)
#       4 end = timer()
#       5 print("Time elapsed in seconds: ",end-start)
#
# ModuleNotFoundError: No module named 'textPreprocess'

# %%
df_new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-94dbd581444b> in <module>
# ----> 1 df_new
#
# NameError: name 'df_new' is not defined

# %%
df_new = detect_lang(df_new,8,9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c7b448af7ab6> in <module>
# ----> 1 df_new = detect_lang(df_new,8,9)
#
# NameError: name 'df_new' is not defined

# %%
plot_lang(df_new,8,9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-1b76e65ee6c2> in <module>
# ----> 1 plot_lang(df_new,8,9)
#
# NameError: name 'df_new' is not defined

# %%
df_new.to_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_transl_21_06_20.xlsx',index=False,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-aaa4ecd583b9> in <module>
# ----> 1 df_new.to_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_transl_21_06_20.xlsx',index=False,encoding='utf-8')
#
# NameError: name 'df_new' is not defined

# %%
df = pd.read_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_transl_21_06_20.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-150b93fa0f85> in <module>
# ----> 1 df = pd.read_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_transl_21_06_20.xlsx')
#       2 df.head()
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ...

# %%
df.isnull().sum()
# Out:
# Short description    0
# Description          0
# Caller               0
# Assignment group     0
# translated_Short     0
# translated_Desc      0
# dtype: int64

# %%
df.translated_Short.fillna(df['Short description'],inplace=True)
df.translated_Desc.fillna(df['Description'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Short description    0
# Description          0
# Caller               0
# Assignment group     0
# translated_Short     0
# translated_Desc      0
# dtype: int64

# %%
df['Short description'] = df['translated_Short']
df['Description'] = df['translated_Desc']
df.drop(['iso_Short','iso_Desc','lang_Short','lang_Desc','translated_Short','translated_Desc'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-04ec79812a79> in <module>
#       1 df['Short description'] = df['translated_Short']
#       2 df['Description'] = df['translated_Desc']
# ----> 3 df.drop(['iso_Short','iso_Desc','lang_Short','lang_Desc','translated_Short','translated_Desc'],axis=1,inplace=True)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
# ...

# %%
df.to_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/translated_input.xlsx',index=False,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-10cee65a37e1> in <module>
# ----> 1 df.to_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/translated_input.xlsx',index=False,encoding='utf-8')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2179             startcol=startcol,
#    2180             freeze_panes=freeze_panes,
# -> 2181             engine=engine,
#    2182         )
#    2183
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
# ...

# %% [markdown]
# ### 3rd translation

# %%
df = pd.read_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/translated_input.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-bf4dfc8881ac> in <module>
# ----> 1 df = pd.read_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/translated_input.xlsx')
#       2 df.head()
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ...

# %%
from textPreprocess import lang_translator_full

lang_translator_full(df,0,1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-b8cc52db6dac> in <module>
# ----> 1 from textPreprocess import lang_translator_full
#       2
#       3 lang_translator_full(df,0,1)
#
# ModuleNotFoundError: No module named 'textPreprocess'

# %%
df['Short description'][164]
# Out:
# ''

# %%
df.to_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_final.xlsx',index=False,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-f986f9769c52> in <module>
# ----> 1 df.to_excel('/content/drive/My Drive/Colab Notebooks/Capstone/Datasets/input_final.xlsx',index=False,encoding='utf-8')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2179             startcol=startcol,
#    2180             freeze_panes=freeze_panes,
# -> 2181             engine=engine,
#    2182         )
#    2183
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
# ...

# %%
from textPreprocess import detect_lang

df = detect_lang(df,0,1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-3fe639722c6a> in <module>
# ----> 1 from textPreprocess import detect_lang
#       2
#       3 df = detect_lang(df,0,1)
#
# ModuleNotFoundError: No module named 'textPreprocess'

# %%
from textPreprocess import plot_lang

plot_lang(df,0,1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-a9864cd5ce20> in <module>
# ----> 1 from textPreprocess import plot_lang
#       2
#       3 plot_lang(df,0,1)
#
# ModuleNotFoundError: No module named 'textPreprocess'
